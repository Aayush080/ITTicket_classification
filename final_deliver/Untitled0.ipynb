# %%
# !python3 "/content/drive/MyDrive/GenieTalk/Ticket_classification/final_deliver/Flaskapp/app.py"
# Out:
# 2021-04-15 13:49:34.792957: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/GenieTalk/Ticket_classification/final_deliver/Flaskapp/app.py", line 11, in <module>
#     model = tf.keras.models.load_model("fastTextmodel.h5")
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/saving/save.py", line 211, in load_model
#     loader_impl.parse_saved_model(filepath)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py", line 114, in parse_saved_model
#     constants.SAVED_MODEL_FILENAME_PB))
# OSError: SavedModel file does not exist at: fastTextmodel.h5/{saved_model.pbtxt|saved_model.pb}
